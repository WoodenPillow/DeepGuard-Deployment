# %%
# Step 1: Install packages
# !pip install -q numpy==2.0.2 joblib pefile streamlit xgboost torch scikit-learn pyngrok fpdf
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 67.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...

# %%
# Step 2: Import required libs
import os
from threading import Thread
from pyngrok import ngrok

# %%
# Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set your ngrok auth token.
ngrok.set_auth_token('2vZXmVoZ4aogtJXBlWyCNAIdZSd_3BGViStWNqnykDFRSZAHU')

# %%
# Step 4: Run Streamlit app
def run_app():
    os.system("streamlit run /content/drive/MyDrive/Ransomware-Detection/Deployment/Home.py --server.port 8888")

# %%
thread = Thread(target=run_app)
thread.start()

# %%
# Open a public ngrok tunnel using the 'addr' parameter.
public_url = ngrok.connect(addr='8888', proto="http", bind_tls=True, hostname="moral-kite-relevant.ngrok-free.app")
print('Your Streamlit app is live at:', public_url)
# Out:
# Your Streamlit app is live at: NgrokTunnel: "https://moral-kite-relevant.ngrok-free.app" -> "http://localhost:8888"

# %%
import time

print ("Start long-running process...")

for i in range (20000):
  print (f"Iteration  {i+1}: Still running...")
  time.sleep(150)

print ("Process completed :D")
# Out:
# Start long-running process...
# Iteration  1: Still running...
# Iteration  2: Still running...
# Iteration  3: Still running...
# Iteration  4: Still running...
# Iteration  5: Still running...
# Iteration  6: Still running...
# Iteration  7: Still running...
# Iteration  8: Still running...
# Iteration  9: Still running...
# Iteration  10: Still running...
# Iteration  11: Still running...
# Iteration  12: Still running...
# Iteration  13: Still running...
# Iteration  14: Still running...
# Iteration  15: Still running...
# Iteration  16: Still running...
# Iteration  17: Still running...
# Iteration  18: Still running...
# Iteration  19: Still running...
# Iteration  20: Still running...
# Iteration  21: Still running...
# Iteration  22: Still running...
# Iteration  23: Still running...
# Iteration  24: Still running...
# Iteration  25: Still running...
# Iteration  26: Still running...
# Iteration  27: Still running...
# Iteration  28: Still running...
# ...
